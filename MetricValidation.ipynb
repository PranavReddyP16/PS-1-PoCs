# %%
df = pd.read_csv('~/Pranav/MachineLearning/DataSets/Pokemon.csv', index_col='#')
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
Leg_type = df.dtypes['Legendary']
print(Leg_type)
# Out:
# bool

# %%
print(len(df[df['Legendary'] == True]))
# Out:
# 65

# %%
print(df.dtypes['Generation'])
# Out:
# int64

# %%
df.loc[df['Total'] >= 600, 'Legendary'] = True

# %%
df.loc[df['Name'].str.contains("Mega"), "Legendary"] = False

# %%
for index, row in df.iterrows() :
    name = row['Name']
    Legendary = row['Legendary']
    if Legendary == True :
        df.loc[df['Name'].str.contains(name), 'Legendary'] = True
df[df['Legendary'] == True].head(10)
# Out:
#                     Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 144             Articuno       Ice    Flying    580   90      85      100
# 145               Zapdos  Electric    Flying    580   90      90       85
# 146              Moltres      Fire    Flying    580   90     100       90
# 149            Dragonite    Dragon    Flying    600   91     134       95
# 150               Mewtwo   Psychic       NaN    680  106     110       90
# 150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
# 150  MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150       70
# 151                  Mew   Psychic       NaN    600  100     100      100
# 243               Raikou  Electric       NaN    580   90      85       75
# 244                Entei      Fire       NaN    580  115     115       85
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 144       95      125     85           1       True
# ...

# %%
df[df['Name'].str.contains("Mew")].loc["Legendary"] = True
print(df[df['Name'].str.contains("Mew")])
# Out:
#                     Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 150               Mewtwo  Psychic       NaN    680  106     110       90
# 150  MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 150  MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150       70
# 151                  Mew  Psychic       NaN    600  100     100      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 150      154       90    130           1       True
# 150      154      100    130           1      False
# 150      194      120    140           1      False
# 151      100      100    100           1       True
# /home/pranav/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df[df['Legendary'] == True].head(20)
# Out:
#           Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 144   Articuno       Ice   Flying    580   90      85      100       95
# 145     Zapdos  Electric   Flying    580   90      90       85      125
# 146    Moltres      Fire   Flying    580   90     100       90      125
# 149  Dragonite    Dragon   Flying    600   91     134       95      100
# 150     Mewtwo   Psychic      NaN    680  106     110       90      154
# 151        Mew   Psychic      NaN    600  100     100      100      100
# 243     Raikou  Electric      NaN    580   90      85       75      115
# 244      Entei      Fire      NaN    580  115     115       85       90
# 245    Suicune     Water      NaN    580  100      75      115       90
# 248  Tyranitar      Rock     Dark    600  100     134      110       95
# 249      Lugia   Psychic   Flying    680  106      90      130       90
# 250      Ho-oh      Fire   Flying    680  106     130       90      110
# ...

# %%
len(df)
# Out:
# 800

# %%
df.head(20)
# Out:
#                          Name Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                   Bulbasaur  Grass  Poison    318  45      49       49
# 2                     Ivysaur  Grass  Poison    405  60      62       63
# 3                    Venusaur  Grass  Poison    525  80      82       83
# 3       VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4                  Charmander   Fire     NaN    309  39      52       43
# 5                  Charmeleon   Fire     NaN    405  58      64       58
# 6                   Charizard   Fire  Flying    534  78      84       78
# 6   CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 6   CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 7                    Squirtle  Water     NaN    314  44      48       65
# 8                   Wartortle  Water     NaN    405  59      63       80
# 9                   Blastoise  Water     NaN    530  79      83      100
# ...

# %%
df[df['Legendary'] == True].head(20)
# Out:
#                         Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 144                 Articuno       Ice    Flying    580   90      85      100
# 145                   Zapdos  Electric    Flying    580   90      90       85
# 146                  Moltres      Fire    Flying    580   90     100       90
# 149                Dragonite    Dragon    Flying    600   91     134       95
# 150                   Mewtwo   Psychic       NaN    680  106     110       90
# 150      MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
# 150      MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150       70
# 151                      Mew   Psychic       NaN    600  100     100      100
# 243                   Raikou  Electric       NaN    580   90      85       75
# 244                    Entei      Fire       NaN    580  115     115       85
# 245                  Suicune     Water       NaN    580  100      75      115
# ...

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import LeavePOut
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import StratifiedKFold

# %%
print(df.shape)
# Out:
# (800, 12)

# %%
df.describe().transpose()
# Out:
#             count       mean         std    min     25%    50%    75%    max
# Total       800.0  435.10250  119.963040  180.0  330.00  450.0  515.0  780.0
# HP          800.0   69.25875   25.534669    1.0   50.00   65.0   80.0  255.0
# Attack      800.0   79.00125   32.457366    5.0   55.00   75.0  100.0  190.0
# Defense     800.0   73.84250   31.183501    5.0   50.00   70.0   90.0  230.0
# Sp. Atk     800.0   72.82000   32.722294   10.0   49.75   65.0   95.0  194.0
# Sp. Def     800.0   71.90250   27.828916   20.0   50.00   70.0   90.0  230.0
# Speed       800.0   68.27750   29.060474    5.0   45.00   65.0   90.0  180.0
# Generation  800.0    3.32375    1.661290    1.0    2.00    3.0    5.0    6.0

# %%
df.loc[df['Total']>=600, 'Legendary'] = True
df[df['Legendary'] == True].head(20)
# Out:
#                           Name    Type 1    Type 2  Total   HP  Attack  \
# #
# 3        VenusaurMega Venusaur     Grass    Poison    625   80     100
# 6    CharizardMega Charizard X      Fire    Dragon    634   78     130
# 6    CharizardMega Charizard Y      Fire    Flying    634   78     104
# 9      BlastoiseMega Blastoise     Water       NaN    630   79     103
# 94           GengarMega Gengar     Ghost    Poison    600   60      65
# 127          PinsirMega Pinsir       Bug    Flying    600   65     155
# 130      GyaradosMega Gyarados     Water      Dark    640   95     155
# 142  AerodactylMega Aerodactyl      Rock    Flying    615   80     135
# 144                   Articuno       Ice    Flying    580   90      85
# 145                     Zapdos  Electric    Flying    580   90      90
# 146                    Moltres      Fire    Flying    580   90     100
# 149                  Dragonite    Dragon    Flying    600   91     134
# ...

# %%
print(df.shape)
# Out:
# (800, 12)

# %%
df.describe().transpose()
# Out:
#             count       mean         std    min     25%    50%    75%    max
# Total       800.0  435.10250  119.963040  180.0  330.00  450.0  515.0  780.0
# HP          800.0   69.25875   25.534669    1.0   50.00   65.0   80.0  255.0
# Attack      800.0   79.00125   32.457366    5.0   55.00   75.0  100.0  190.0
# Defense     800.0   73.84250   31.183501    5.0   50.00   70.0   90.0  230.0
# Sp. Atk     800.0   72.82000   32.722294   10.0   49.75   65.0   95.0  194.0
# Sp. Def     800.0   71.90250   27.828916   20.0   50.00   70.0   90.0  230.0
# Speed       800.0   68.27750   29.060474    5.0   45.00   65.0   90.0  180.0
# Generation  800.0    3.32375    1.661290    1.0    2.00    3.0    5.0    6.0

# %%
df.loc[df[ 'Legendary'] == True, 'Legendary'] = 1
df.loc[df[ 'Legendary'] == False, 'Legendary'] = 0

df.head(20)
# Out:
#                          Name Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                   Bulbasaur  Grass  Poison    318  45      49       49
# 2                     Ivysaur  Grass  Poison    405  60      62       63
# 3                    Venusaur  Grass  Poison    525  80      82       83
# 3       VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4                  Charmander   Fire     NaN    309  39      52       43
# 5                  Charmeleon   Fire     NaN    405  58      64       58
# 6                   Charizard   Fire  Flying    534  78      84       78
# 6   CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 6   CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 7                    Squirtle  Water     NaN    314  44      48       65
# 8                   Wartortle  Water     NaN    405  59      63       80
# 9                   Blastoise  Water     NaN    530  79      83      100
# ...

# %%
df.describe().transpose()
# Out:
#             count       mean         std    min     25%    50%    75%    max
# Total       800.0  435.10250  119.963040  180.0  330.00  450.0  515.0  780.0
# HP          800.0   69.25875   25.534669    1.0   50.00   65.0   80.0  255.0
# Attack      800.0   79.00125   32.457366    5.0   55.00   75.0  100.0  190.0
# Defense     800.0   73.84250   31.183501    5.0   50.00   70.0   90.0  230.0
# Sp. Atk     800.0   72.82000   32.722294   10.0   49.75   65.0   95.0  194.0
# Sp. Def     800.0   71.90250   27.828916   20.0   50.00   70.0   90.0  230.0
# Speed       800.0   68.27750   29.060474    5.0   45.00   65.0   90.0  180.0
# Generation  800.0    3.32375    1.661290    1.0    2.00    3.0    5.0    6.0

# %%
df.dtypes
# Out:
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary     object
# dtype: object

# %%
df.loc[:, 'Legendary'] = pd.to_numeric(df['Legendary'])
print(df.dtypes['Legendary'])
# Out:
# int64

# %%
df.dtypes
# Out:
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary      int64
# dtype: object

# %%
df.describe().transpose()
# Out:
#             count       mean         std    min     25%    50%    75%    max
# Total       800.0  435.10250  119.963040  180.0  330.00  450.0  515.0  780.0
# HP          800.0   69.25875   25.534669    1.0   50.00   65.0   80.0  255.0
# Attack      800.0   79.00125   32.457366    5.0   55.00   75.0  100.0  190.0
# Defense     800.0   73.84250   31.183501    5.0   50.00   70.0   90.0  230.0
# Sp. Atk     800.0   72.82000   32.722294   10.0   49.75   65.0   95.0  194.0
# Sp. Def     800.0   71.90250   27.828916   20.0   50.00   70.0   90.0  230.0
# Speed       800.0   68.27750   29.060474    5.0   45.00   65.0   90.0  180.0
# Generation  800.0    3.32375    1.661290    1.0    2.00    3.0    5.0    6.0
# Legendary   800.0    0.13000    0.336514    0.0    0.00    0.0    0.0    1.0

# %%
x1 = df.drop(['Legendary', 'Name', 'Type 1', 'Type 2'], axis=1).values
y1 = df['Legendary'].values

# %%
import time

# %% [markdown]
# Holdout Validation Method

# %%
start_time = time.time()
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(x1, y1, test_size = 0.30, random_state = 100)
model = LogisticRegression()
model.fit(X_train, Y_train)
result = model.score(X_test, Y_test)

print("Accuracy is : %.2f%%" % (result*100))
print(time.time()-start_time)
# Out:
# Accuracy is : 97.92%
# 0.034403085708618164
# /home/pranav/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %% [markdown]
# K-Fold Cross-Validation

# %%
start_time = time.time()
kfold = model_selection.KFold(n_splits = 10, random_state = 100)
model_kfold = LogisticRegression()
results_kfold = model_selection.cross_val_score(model_kfold, x1, y1, cv = kfold)
print("Accuracy is : %.2f%%" % (results_kfold.mean()*100))
print(time.time()-start_time)
# Out:
# /home/pranav/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# /home/pranav/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/pranav/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...

# %% [markdown]
# Stratified K-Fold Cross Validation

# %%
start_time = time.time()
skfold = StratifiedKFold(n_splits = 3, random_state = 100)
model_skfold = LogisticRegression()
results_skfold = model_selection.cross_val_score(model_skfold, x1, y1, cv = skfold)
print("Accuracy is : %.2f%%" % (results_skfold.mean()*100))
print(time.time()-start_time)
# Out:
# Accuracy is : 98.25%
# 0.09890580177307129
# /home/pranav/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# /home/pranav/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# ...

# %% [markdown]
# Leave One Out Cross Validation

# %%
start_time = time.time()
loocv = model_selection.LeaveOneOut()
model_loocv = LogisticRegression()
results_loocv = model_selection.cross_val_score(model_loocv, x1, y1, cv = loocv)
print("Accuracy is : %.2f%%" % (results_loocv.mean()*100))
print(time.time()-start_time)
# Out:
# /home/pranav/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/pranav/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
start_time = time.time()
kfold2 = model_selection.ShuffleSplit(n_splits=10, test_size=0.30, random_state=100)
model_shufflecv = LogisticRegression()
results_4 = model_selection.cross_val_score(model_shufflecv, x1, y1, cv=kfold2)
print("Accuracy: %.2f%% (%.2f%%)" % (results_4.mean()*100.0, results_4.std()*100.0))
print(time.time()-start_time)
# Out:
# /home/pranav/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/pranav/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...
